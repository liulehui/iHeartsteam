# %%
import json
import pandas as pd
import numpy as np
import scipy as sp
import re
from string import punctuation
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import nltk
from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# # Load data

# %%
def parse(path):
  g = open(path, 'r',encoding='utf-8')
  for l in g:
    yield eval(l)

# %%
def remove_non_ascii(word):
    word = word.lower()
    word = ''.join([i for i in word if i.isalnum() and ord(i) < 128 ])
    return word

# %%
def textcleaned(sentence):
    sentence = sentence.lower()
    ps = PorterStemmer()#Add a stemer
    lemmatizer = WordNetLemmatizer()#Add a Lemmatizer

    # split into words
    tokens = word_tokenize(sentence)
    
    # remove punctuation
    table = str.maketrans('', '', punctuation)
    stripped = [w.translate(table) for w in tokens]
    
    # remove other lauguages and some special character
    words = [remove_non_ascii(word) for word in stripped]
    
    # filter out stop words
    stop_words = set(stopwords.words('english'))
    words = [lemmatizer.lemmatize(w) for w in words if not w in stop_words]#Stem words
    
    # stemming of words
#     porter = PorterStemmer()
#     words = [porter.stem(word) for word in words]
    
    return ' '.join(words)

# %%
reviews = []
counter = 0
for i in parse("australian_user_reviews.json"):
    dump = json.dumps(i)   
    load = json.loads(dump)
    counter += 1
    if counter%1000 == 0:
        print(counter)
    for i in range(len(load['reviews'])):
        # filter out some non-english reviews and remove stop-words
        load['reviews'][i]['review'] = textcleaned(load['reviews'][i]['review'])
        observation = [load['user_id'],load['reviews'][i]['item_id'],load['reviews'][i]['recommend'],load['reviews'][i]['review']]
        reviews.append(observation)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000

# %%
df.to_pickle('review_lemma.pkl')

# %%
df = pd.DataFrame(reviews)
df.columns = ['user_id', 'item_id','isRecommend','reviews']
print(df.shape)
df.head(n=20)
# Out:
# (59305, 4)
#               user_id item_id  isRecommend  \
# 0   76561197970982479    1250         True
# 1   76561197970982479   22200         True
# 2   76561197970982479   43110         True
# 3             js41637  251610         True
# 4             js41637  227300         True
# 5             js41637  239030         True
# 6           evcentric  248820         True
# 7           evcentric  370360         True
# 8           evcentric  237930         True
# 9           evcentric  263360         True
# 10          evcentric  107200         True
# 11          evcentric  224500         True
# 12              doctr  250320         True
# 13              doctr   20920         True
# 14              doctr  204100         True
# 15              doctr  224600         True
# 16              doctr  207610         True
# 17              doctr  108710         True
# 18          maplemage  211420         True
# 19          maplemage  211820         True
#
#                                               reviews
# 0   simple yet great replayability  opinion  zombi...
# 1                           unique worth playthrough
# 2   great atmosphere  gunplay bit chunky time end ...
# 3   know think see title  barbie dreamhouse party ...
# 4   simple  actually simple   truck driving simula...
# 5   fun little game play bored time passer  gud  r...
# 6   suitably punishing roguelike platformer  winni...
# 7                            run fun  hell kind fun
# 8   elegant integration gameplay  story  world dev...
# 9   random drop random quest  stat point  animatio...
# 10  fun balance tactic strategy  potential rewardi...
# 11  fun world builder  plenty option want challeng...
# 12  game  fun  fight sequence improved walking dea...
# 13  really really really great game  good story  i...
# 14  buy already  great story  great multiplayer go...
# 15  great game played  right need find actual down...
# 16  ending game      buy  invested  im automatical...
# 17  alan wake really good game  light effect prett...
# 18                                            git gud
# 19  like terrarium  play 9 hour straight  get endg...

# %% [markdown]
# # NLP Generator

# %%
# https://www.cs.uic.edu/~liub/FBS/sentiment-analysis.html#lexicon
# Use the positive word dict and negative word dict in the URL
with open('positive-words.txt') as f:
    pos_dict=f.readlines()
pos_dict=[x[:-1] for x in pos_dict if x[0]!=';']
pos_dict=[x for x in pos_dict if len(x)!=0]
pos_set=set(pos_dict)
pos_set.add('true')# add one more item "true"

with open('negative-words.txt') as f:
    neg_dict=f.readlines()
neg_dict=[x[:-1] for x in neg_dict if x[0]!=';']
neg_dict=[x for x in neg_dict if len(x)!=0]
neg_set=set(neg_dict)

def get_sentiment(review_obj):
    ls=review_obj.split(' ')
    if ls[0]=='true':
#         if the first word is true, which means this item is recommended
#  we record the sentiment to be 1
# Then we count the number of positive words in the review,
# and assign this number to be the positive sentiment
        return sum([1 for x in ls if x in pos_set])
    else:
# do the same for the negative words
        return -sum([1 for x in ls if x in neg_set])
# But denote the negative sentiment as "-" negative numbers

# %%
df['Recommend_reviews']=df.isRecommend.astype(str).str.lower()+' '+df.reviews.str.lower()
# Add isRecommend as a string to the review, so if it is true, the sentiment equals 1 by default
# If it is false, the sentiment equals -1 by default

# %%
df['sentiment']=df.Recommend_reviews.apply(get_sentiment)
# Generate this sentiment column

# %% [markdown]
# # Data Checking

# %%
df[df['isRecommend'] ==False]
# Out:
#                      user_id item_id  isRecommend  \
# 48         76561198043472122   33440        False
# 62         76561198066046412  359320        False
# 68         76561198070565427     570        False
# 84                   boydeer  383080        False
# 122              sandwiches1  417860        False
# 132    iamthekingofbrowntown  344760        False
# 156        76561198010674657  377160        False
# 183                Nozomikat  437220        False
# 186               xfluttersx  202530        False
# 193            ii_voltage_ii  253710        False
# 203                 Xx-Woods  346330        False
# 226        76561198073784601  299740        False
# 241                AVATAR715   48240        False
# 258                Koolcaz12  298050        False
# 263                 97396295  218230        False
# 264                 97396295  291550        False
# 279     DieMadchenschanderin  380770        False
# 281     DieMadchenschanderin  227680        False
# 282                 GGargula     570        False
# 286       getf0kinn0sc0pedm9     440        False
# 296              ohnospaghet  252490        False
# 300               2768820078     730        False
# 305               2768820078  222420        False
# 310        76561198056392326  219640        False
# 311        76561198056392326  269210        False
# 312                 2d4nk4m3  317470        False
# 318       EizanAratoFujimaki  359550        False
# 322                   TeCool  314130        False
# 327              washington_     440        False
# 336        76561198088944293  218230        False
# ...                      ...     ...          ...
# 58948           NamerGamer69  269290        False
# 58951      76561198153660339  224580        False
# 58977           AlphaPodbury  242050        False
# 58985            cranialperv  209630        False
# 58995                Azzaaaa  261640        False
# 59003             GamingDope  387970        False
# 59009                 ButNae  113400        False
# 59034              Slicorice     730        False
# 59037      76561198166303039     730        False
# 59061                Mooseox  417860        False
# 59086                pingaas  200510        False
# 59087   DreamingTillDawnAlt2  295110        False
# 59139           danebuchanan  295110        False
# 59144           danebuchanan  311210        False
# 59154                K1NGCJS  412880        False
# 59166         laislabonita75  305920        False
# 59180      76561198204448251  301520        False
# 59193      76561198208704549  389430        False
# 59215      76561198209894493     570        False
# 59223      76561198219561792  209650        False
# 59225      76561198222628548  370240        False
# 59236           112367263762  304050        False
# 59244      76561198236893796  391460        False
# 59248               AusBacon  369290        False
# 59254                wayfeng    4000        False
# 59262            kimjongadam  273110        False
# 59268          iwishihadaids  391460        False
# 59283           MeloncraftLP  265630        False
# 59284      76561198277602337  306130        False
# 59285                 943525  298110        False
#
#                                                  reviews  \
# 48                                          game nt work
# 62              charged 80 15 dollar  got boring 5 hour
# 68                                                    w
# 84
# 122                                           emily thot
# 132    spent 3 day making base  man teleported base  ...
# 156    begin  trusted bethesda  time spent fo3  never...
# 183    harsh new player  combat system strange still ...
# 186    got worse sonic 06   played many sonic game ki...
# 193    game actually free play  nt think  hunt one an...
# 203    o zumbis rpidos e fortes  o humanos lerdos e f...
# 226                                game waste dont buy
# 241                          send code play  waste money
# 258                                    stellaris better
# 263    wtf keep crashing plz fixxxxxxxxxxxxxxxxxxxxxx...
# 264                  bad  people spam 1 op character 110
# 279    well  nt much say game  north american shut  l...
# 281    buy  support  awesome  find dont kek  old repo...
# 282                         problemas com serve e conexo
# 286    well valve u screwed pyros overpowered new upd...
# 296           every new update make game crash fasterlol
# 300                                               derank
# 305                                  ps298um3d982dps2ps2
# 310                                                 200
# 311
# 312    fun game look  big microtransaction festit req...
# 318    sale un error de nat estricto da paja configur...
# 322    decided buy item wanted  think buying individu...
# 327    bootleg super nintendo brothersif u money real...
# 336                                                noice
# ...                                                  ...
# 58948  ing paid 15  doesnt even ing work crash ing ba...
# 58951                                 dont know get game
# 58977  uplay reasoncant reboot  get 1030 fps  frequen...
# 58985                        terrible game  abort  abort
# 58995  borderland 2 one favourite game pumped sequel ...
# 59003                                               play
# 59009
# 59034                                         pretty gay
# 59037                       put ad gun got perfect game
# 59061  actuly liked emily brad  he nasty lovely girl ...
# 59086  attention  user 219 monitor purchase unless wa...
# 59087  h1z1 storydestiny purchase h1z1  nt buy game f...
# 59139  game broken  hacker everywhere really boringi ...
# 59144  game complete canceri would rather drink bleac...
# 59154                game ing rip farming simulator 2017
# 59166                 really nt like  sorry  slow boring
# 59180  armour electroshields  came back week ago pref...
# 59193  steam e kmadan nce oynuyordum tavsiye etmiyoru...
# 59215  dota 2normal skill  2ez  high skill  still 2ez...
# 59223                         game take alot ram memory
# 59225  simply horrible  always lag always get frozen ...
# 59236              mouse keep spazzing reason razer naga
# 59244                                               fish
# 59248
# 59254                           good game  nt reccomend
# 59262             well review give ripoff c nt even work
# 59268                                                bad
# 59283  nt install game                        ggggggg...
# 59284  game terrible   iv tried 15hrs tryin play ever...
# 59285                                   uplay  everytime
#
#                                        Recommend_reviews  sentiment
# 48                                    false game nt work         -1
# 62       false  charged 80 15 dollar  got boring 5 hour          -2
# 68                                              false w          -1
# 84                                                false          -1
# 122                                     false emily thot         -1
# 132    false spent 3 day making base  man teleported ...         -3
# 156    false begin  trusted bethesda  time spent fo3 ...        -16
# 183    false harsh new player  combat system strange ...         -4
# 186    false got worse sonic 06   played many sonic g...         -6
# 193    false game actually free play  nt think  hunt ...         -2
# 203    false o zumbis rpidos e fortes  o humanos lerd...         -1
# 226                          false game waste dont buy           -2
# 241                    false send code play  waste money         -2
# 258                              false stellaris better          -1
# 263    false wtf keep crashing plz fixxxxxxxxxxxxxxxx...         -2
# 264            false bad  people spam 1 op character 110         -2
# 279    false well  nt much say game  north american s...         -6
# 281    false buy  support  awesome  find dont kek  ol...         -7
# 282                   false problemas com serve e conexo         -1
# 286    false well valve u screwed pyros overpowered n...         -5
# 296     false every new update make game crash fasterlol         -2
# 300                                         false derank         -1
# 305                            false ps298um3d982dps2ps2         -1
# 310                                          false  200          -1
# 311                                             false            -1
# 312    false fun game look  big microtransaction fest...         -3
# 318    false sale un error de nat estricto da paja co...         -2
# 322    false decided buy item wanted  think buying in...         -2
# 327    false bootleg super nintendo brothersif u mone...         -2
# 336                                          false noice         -1
# ...                                                  ...        ...
# 58948  false ing paid 15  doesnt even ing work crash ...         -2
# 58951                           false dont know get game         -1
# 58977  false uplay reasoncant reboot  get 1030 fps  f...         -1
# 58985                  false terrible game  abort  abort         -4
# 58995  false borderland 2 one favourite game pumped s...         -1
# 59003                                        false  play         -1
# 59009                                             false          -1
# 59034                                   false pretty gay         -1
# 59037                 false put ad gun got perfect game          -1
# 59061  false actuly liked emily brad  he nasty lovely...         -2
# 59086  false attention  user 219 monitor purchase un
# <b>limit_output extension: Maximum message size of 10000 exceeded with 14393 characters</b>

# %%
df[df['user_id'] == '76561198070565427']
# Out:
#               user_id item_id  isRecommend  \
# 65  76561198070565427  218620         True
# 66  76561198070565427  208090         True
# 67  76561198070565427  242700         True
# 68  76561198070565427     570        False
# 69  76561198070565427  224260         True
#
#                                               reviews  \
# 65   5 steampayday 25payday2   1  5002  3  4  5   ...
# 66                                          well dont
# 67                                             100100
# 68                                                 w
# 69
#
#                                     Recommend_reviews  sentiment
# 65  true  5 steampayday 25payday2   1  5002  3  4 ...          1
# 66                                     true well dont          2
# 67                                        true 100100          1
# 68                                           false w          -1
# 69                                              true           1
